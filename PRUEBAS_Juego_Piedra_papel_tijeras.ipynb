# %% [markdown]
# # Piedra Papel & Tijera
#
# - Reglas del Juego "Piedra, Papel y Tijera":
#
#     - Dos jugadores eligen una de las tres opciones: "Piedra", "Papel" o "Tijera".
#
#     - Las reglas para determinar al ganador son:
#
#         - Piedra vence a Tijera.
#
#         - Tijera vence a Papel.
#
#         - Papel vence a Piedra.
#
#         - El jugador que gana una ronda obtiene un punto.
#
#         - El juego continúa hasta que un jugador haya acumulado 3 puntos, convirtiéndose en el ganador.
#
#
# - Pistas para las alumnas:
#
#     1. Comienza por definir el número de puntos objetivo que se deben alcanzar para ganar el juego.
#
#     2. Implementa una función que obtenga la elección del jugador y valide que sea una de las opciones válidas ("Piedra", "Papel" o "Tijera").
#
#     3. Utiliza un bucle `while` para llevar un registro de los puntos de cada jugador y continuar el juego hasta que se alcance el número de puntos objetivo.
#
#     4. Genera una elección aleatoria para el segundo jugador (la computadora) utilizando el módulo `random`.
#
#     5. Determina al ganador de cada ronda y actualiza los puntos correspondientes.
#
#     6. Verifica si algún jugador ha alcanzado el número de puntos objetivo y finalicen el juego cuando eso suceda.

# %% [markdown]
# **PSEUDO CÓDIGO**

# %% [markdown]
# opcion_jugador
#
# opcion_maquina (random??)
#
#
#
#         Si la opción del jugador es igual a la del ordenador:
#             Print (‘¡Empate!’)
#
#         Si la opción del jugador es "piedra”:
#             Si la opción de la máquina es "tijera":
#                 Print(‘¡Has ganado! La piedra rompe la tijera).”
#             Else:
#                 Print(‘¡Has perdido! El papel envuelve la piedra’)
#
#         Si la opción del jugador es "papel":
#             Si la opción del ordenador es "piedra":
#                 Print(‘¡Has ganado! El papel envuelve a la piedra’)
#             Else:
#                 Print(‘¡Has perdido! Las tijeras cortan el papel’)
#
# 	Si la opción del usuario es ‘tijera’:
# 		Si jugada de la computadora es "papel" entonces:
#                 Print(‘¡Has ganado!’ La tijera corta el papel’)
#             Else:
#                 Print(‘¡Has perdido! La piedra rompe la tijera’)

# %% [markdown]
# **EMPEZAMOS CON EL CÓDIGO DE VERDAD**

# %%
jugador = input( 'piedra, papel, tijera ')
jugador = jugador.lower()
ordenador = random.choice(opciones

# %%
import random

puntos_jugador = 0
puntos_ordenador = 0
opciones = ('piedra','papel','tijera') 

nombre = input('¿Cómo te llamas?')
print('Hola', nombre, '¡empecemos a jugar!')
print('Recuerda que, una vez comenzado el juego, puedes abandonarlo pulsando la tecla x en lugar de escribir una opción.')
print('________________________________________________________')

while puntos_jugador < 3 and puntos_ordenador < 3:
    jugador = input('Escribe piedra, papel o tijera').lower()
    ordenador = random.choice(opciones)

    if jugador == 'x':
          print('Has abandonado el juego. ¡Hasta pronto!')
          break
    
    if jugador not in opciones:
      print('Opción inválida. Escoge entre piedra, papel o tijera')
      print('________________________________________________________')
      
    else:

      if jugador == ordenador:
        print(f'Los dos habéis escogido {jugador}. Vais {puntos_jugador} - {puntos_ordenador}')
        print('________________________________________________________')
      elif jugador == 'piedra':
        if ordenador == 'tijera':
          puntos_jugador += 1 
          print(f"Has escogido {jugador} y el ordenador, {ordenador}. Has ganado: la piedra rompe la tijera. Vais {puntos_jugador} - {puntos_ordenador}")
          print('________________________________________________________')
        else:
          puntos_ordenador +=1
          print(f"Has perdido: el papel envuelve a la piedra. Vais {puntos_jugador} - {puntos_ordenador}")
          print('________________________________________________________')
      elif jugador == 'papel':
        if ordenador == 'piedra':
          puntos_jugador +=1
          print(f"Has escogido {jugador} y el ordenador, {ordenador}. Has ganado: el papel envuelve a la piedra. Vais {puntos_jugador} - {puntos_ordenador}")
          print('________________________________________________________')
        else:
          puntos_ordenador +=1
          print(f"Has escogido {jugador} y el ordenador, {ordenador}. Has perdido: la tijera corta el papel. Vais {puntos_jugador} - {puntos_ordenador}")
          print('________________________________________________________')
        
      elif jugador == 'tijera':
        if ordenador == 'papel':
          puntos_jugador +=1
          print(f"Has escogido {jugador} y el ordenador, {ordenador}. Has ganado: la tijera corta el papel. Vais {puntos_jugador} - {puntos_ordenador}")
          print('________________________________________________________')
        else:
          puntos_ordenador +=1
          print(f"Has escogido {jugador} y el ordenador, {ordenador}. Has perdido: la piedra rompe la tijera. Vais {puntos_jugador} - {puntos_ordenador}")
          print('________________________________________________________')


if puntos_jugador > puntos_ordenador:
    print(f'¡Enhorabuena, {nombre}, has ganado el juego! El resultado final es {puntos_jugador} - {puntos_ordenador}')
    print('________________________________________________________')
    

else:
    print(f'¡Lo sentimos, {nombre}, has perdido el juego! El resultado final es {puntos_jugador} - {puntos_ordenador} ¡Vuelve a intentarlo!')
    print('________________________________________________________')
# Out:
# Hola Reyes ¡empecemos a jugar!
# Recuerda que, una vez comenzado el juego, puedes abandonarlo pulsando la tecla x en lugar de escribir una opción.
# ________________________________________________________
# Has escogido piedra y el ordenador, tijera. Has ganado: la piedra rompe la tijera. Vais 1 - 0
# ________________________________________________________
# Los dos habéis escogido papel. Vais 1 - 0
# ________________________________________________________
# Has escogido tijera y el ordenador, papel. Has ganado: la tijera corta el papel. Vais 2 - 0
# ________________________________________________________
# Has abandonado el juego. ¡Hasta pronto!
# ¡Enhorabuena, Reyes, has ganado el juego! El resultado final es 2 - 0
# ________________________________________________________

# %% [markdown]
# **CÓDIGO PARA PRUEBAS**

# %%
import random

puntos_jugador = 0
puntos_ordenador = 0
opciones = ('piedra','papel','tijera') 

nombre = input('¿Cómo te llamas?')
print('Hola', nombre, '¡empecemos a jugar!')
print('________________________________________________________')


while puntos_jugador < 3 and puntos_ordenador < 3:
  jugador = input('Escribe piedra, papel o tijera').lower()
  ordenador = random.choice(opciones)

  if jugador == 'x':
        print('Has abandonado el juego. ¡Hasta pronto!')
        break
  
  elif jugador not in opciones:
    print('Opción inválida. Escoge entre piedra, papel o tijera')
    
  else:

    if jugador == ordenador:
      print(f'Los dos habéis escogido {jugador}. Vais {puntos_jugador} - {puntos_ordenador}')
    elif jugador == 'piedra':
      if ordenador == 'tijera':
        puntos_jugador += 1 
        print(f"Has escogido {jugador} y el ordenador, {ordenador}. Has ganado: la piedra rompe la tijera. Vais {puntos_jugador} - {puntos_ordenador}")
        print('________________________________________________________')
      else:
        puntos_ordenador +=1
        print(f"Has perdido: el papel envuelve a la piedra. Vais {puntos_jugador} - {puntos_ordenador}")
        print('________________________________________________________')
    elif jugador == 'papel':
      if ordenador == 'piedra':
        puntos_jugador +=1
        print(f"Has escogido {jugador} y el ordenador, {ordenador}. Has ganado: el papel envuelve a la piedra. Vais {puntos_jugador} - {puntos_ordenador}")
        print('________________________________________________________')
      else:
        puntos_ordenador +=1
        print(f"Has escogido {jugador} y el ordenador, {ordenador}. Has perdido: la tijera corta el papel. Vais {puntos_jugador} - {puntos_ordenador}")
        print('________________________________________________________')
      
    elif jugador == 'tijera':
      if ordenador == 'papel':
        puntos_jugador +=1
        print(f"Has escogido {jugador} y el ordenador, {ordenador}. Has ganado: la tijera corta el papel. Vais {puntos_jugador} - {puntos_ordenador}")
        print('________________________________________________________')
      else:
        puntos_ordenador +=1
        print(f"Has escogido {jugador} y el ordenador, {ordenador}. Has perdido: la piedra rompe la tijera. Vais {puntos_jugador} - {puntos_ordenador}")
        print('________________________________________________________')


if puntos_jugador > puntos_ordenador:
    print(f'¡Enhorabuena, {nombre}, has ganado el juego! El resultado final es {puntos_jugador} - {puntos_ordenador}')
    

else:
    print(f'¡Lo sentimos, {nombre}, has perdido el juego! El resultado final es {puntos_jugador} - {puntos_ordenador} ¡Vuelve a intentarlo!')
# Out:
# Hola Reyes ¡empecemos a jugar!
# ________________________________________________________
# Los dos habéis escogido piedra. Vais 0 - 0
# Has escogido papel y el ordenador, piedra. Has ganado: el papel envuelve a la piedra. Vais 1 - 0
# ________________________________________________________
# Has abandonado el juego. ¡Hasta pronto!
# ¡Enhorabuena, Reyes, has ganado el juego! El resultado final es 1 - 0

# %% [markdown]
# **MAS PRUEBAS**

# %%
import random

puntos_jugador = 0
puntos_ordenador = 0
opciones = ('piedra','papel','tijera') 

nombre = input('¿Cómo te llamas?')
print('Hola', nombre, '¡empecemos a jugar!')
print('Recuerda que el papel gana a la piedra, la tijera al papel y la piedra a la tijera')
print('Una vez comenzado el juego, puedes abandonarlo pulsando la tecla x')
print('___________________________________________________________________')


while puntos_jugador < 3 and puntos_ordenador < 3:
    jugador = input('Escribe piedra, papel o tijera').lower()
    if jugador == 'x':
        print('Has abandonado el juego. ¡Hasta pronto!')
        break
    if jugador not in opciones:
        print('Opción inválida. Escoge entre piedra, papel o tijera.')
        print('______________________________________________________________________________')

        continue

    ordenador = random.choice(opciones)


    if jugador == ordenador:
        print(f'Los dos habéis escogido {jugador}. Vais {puntos_jugador} - {puntos_ordenador}.')
        print('______________________________________________________________________________')
    elif jugador == 'piedra':
        if ordenador == 'tijera':
            puntos_jugador += 1 
            print(f"Has escogido {jugador} y el ordenador, {ordenador}. ¡Has ganado! Vais {puntos_jugador} - {puntos_ordenador}")
            print('__________________________________________________________________________')
        else:
            puntos_ordenador +=1
            print(f"¡Has perdido! Vais {puntos_jugador} - {puntos_ordenador}.")
            print('__________________________________________________________________________')
    elif jugador == 'papel':
        if ordenador == 'piedra':
            puntos_jugador +=1
            print(f"Has escogido {jugador} y el ordenador, {ordenador}. ¡Has ganado! Vais {puntos_jugador} - {puntos_ordenador}.")
            print('__________________________________________________________________________')
        else:
            puntos_ordenador +=1
            print(f"Has escogido {jugador} y el ordenador, {ordenador}. Has perdido... Vais {puntos_jugador} - {puntos_ordenador}.")
            print('__________________________________________________________________________')
    elif jugador == 'tijera':
        if ordenador == 'papel':
            puntos_jugador +=1
            print(f"Has escogido {jugador} y el ordenador, {ordenador}. ¡Has ganado! Vais {puntos_jugador} - {puntos_ordenador}.")
            print('__________________________________________________________________________')
        else:
            puntos_ordenador +=1
            print(f"Has escogido {jugador} y el ordenador, {ordenador}. Has perdido... Vais {puntos_jugador} - {puntos_ordenador}.")
            print('__________________________________________________________________________')

if jugador != 'x':  # Añadido para evitar imprimir el mensaje de victoria si el usuario abandona mientras está ganando
    if puntos_jugador > puntos_ordenador:
        print(f'¡Enhorabuena, {nombre}, has ganado el juego! El resultado final es {puntos_jugador} - {puntos_ordenador}.')
    elif puntos_jugador < puntos_ordenador:
        print(f'¡Lo sentimos, {nombre}, has perdido el juego! El resultado final es {puntos_jugador} - {puntos_ordenador} ¡Vuelve a intentarlo!')
    else:
        print(f'¡El juego terminó en empate! El resultado final es {puntos_jugador}.')
# Out:
# Hola Reyes ¡empecemos a jugar!
# Recuerda que el papel gana a la piedra, la tijera al papel y la piedra a la tijera
# Una vez comenzado el juego, puedes abandonarlo pulsando la tecla x
# ___________________________________________________________________
# Los dos habéis escogido papel. Vais 0 - 0.
# ______________________________________________________________________________
# Has escogido piedra y el ordenador, tijera. ¡Has ganado! Vais 1 - 0
# __________________________________________________________________________
# Los dos habéis escogido tijera. Vais 1 - 0.
# ______________________________________________________________________________
# Has escogido papel y el ordenador, tijera. Has perdido... Vais 1 - 1.
# __________________________________________________________________________
# Opción inválida. Escoge entre piedra, papel o tijera.
# ______________________________________________________________________________
# Los dos habéis escogido piedra. Vais 1 - 1.
# ______________________________________________________________________________
# Has escogido papel y el ordenador, tijera. Has perdido... Vais 1 - 2.
# __________________________________________________________________________
# Has escogido tijera y el ordenador, piedra. Has perdido... Vais 1 - 3.
# __________________________________________________________________________
# ¡Lo sentimos, Reyes, has perdido el juego! El resultado final es 1 - 3 ¡Vuelve a intentarlo!
